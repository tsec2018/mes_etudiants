# %% [markdown]
# <a href="https://colab.research.google.com/github/tsec2018/mes_etudiants/blob/main/examples/nlp/ipynb/active_learning_review_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Review Classification using Active Learning
#
# **Author:** [Darshan Deshpande](https://twitter.com/getdarshan)<br>
# **Date created:** 2021/10/29<br>
# **Last modified:** 2024/05/08<br>
# **Description:** Demonstrating the advantages of active learning through review classification.

# %% [markdown]
# ## Introduction
#
# With the growth of data-centric Machine Learning, Active Learning has grown in popularity
# amongst businesses and researchers. Active Learning seeks to progressively
# train ML models so that the resultant model requires lesser amount of training data to
# achieve competitive scores.
#
# The structure of an Active Learning pipeline involves a classifier and an oracle. The
# oracle is an annotator that cleans, selects, labels the data, and feeds it to the model
# when required. The oracle is a trained individual or a group of individuals that
# ensure consistency in labeling of new data.
#
# The process starts with annotating a small subset of the full dataset and training an
# initial model. The best model checkpoint is saved and then tested on a balanced test
# set. The test set must be carefully sampled because the full training process will be
# dependent on it. Once we have the initial evaluation scores, the oracle is tasked with
# labeling more samples; the number of data points to be sampled is usually determined by
# the business requirements. After that, the newly sampled data is added to the training
# set, and the training procedure repeats. This cycle continues until either an
# acceptable score is reached or some other business metric is met.
#
# This tutorial provides a basic demonstration of how Active Learning works by
# demonstrating a ratio-based (least confidence) sampling strategy that results in lower
# overall false positive and negative rates when compared to a model trained on the entire
# dataset. This sampling falls under the domain of *uncertainty sampling*, in which new
# datasets are sampled based on the uncertainty that the model outputs for the
# corresponding label. In our example, we compare our model's false positive and false
# negative rates and annotate the new data based on their ratio.
#
# Some other sampling techniques include:
#
# 1. [Committee sampling](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Using multiple models to vote for the best data points to be sampled
# 2. [Entropy reduction](https://www.researchgate.net/publication/51909346_Committee-Based_Sample_Selection_for_Probabilistic_Classifiers):
# Sampling according to an entropy threshold, selecting more of the samples that produce the highest entropy score.
# 3. [Minimum margin based sampling](https://arxiv.org/abs/1906.00025v1):
# Selects data points closest to the decision boundary

# %% [markdown]
# ## Importing required libraries

# %%
import os

os.environ["KERAS_BACKEND"] = "tensorflow"  # @param ["tensorflow", "jax", "torch"]
import keras
from keras import ops
from keras import layers
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()

# %% [markdown]
# ## Loading and preprocessing the data
#
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000
# reviews in total, including training and testing splits. We will merge these splits and
# sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# Total examples: 50000

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
vectorizer = layers.TextVectorization(
    3000, standardize="lower_and_strip_punctuation", output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=4, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.keras", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.keras")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 150, 128)       │       384,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 150, 64)        │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d            │ (None, 64)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - binary_accuracy: 0.6468 - false_negatives: 2004.2930 - false_positives: 5086.8853 - loss: 0.6431
# Epoch 1: val_loss improved from inf to 0.55187, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 15s 47ms/step - binary_accuracy: 0.6468 - false_negatives: 2025.9241 - false_positives: 5107.0190 - loss: 0.6430 - val_binary_accuracy: 0.7260 - val_false_negatives: 369.0000 - val_false_positives: 1001.0000 - val_loss: 0.5519
# Epoch 2/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7728 - false_negatives: 1678.7307 - false_positives: 2899.7371 - loss: 0.5079
# Epoch 2: val_loss improved from 0.55187 to 0.43699, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.7728 - false_negatives: 1705.7468 - false_positives: 2928.9050 - loss: 0.5077 - val_binary_accuracy: 0.8088 - val_false_negatives: 625.0000 - val_false_positives: 331.0000 - val_loss: 0.4370
# Epoch 3/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8246 - false_negatives: 1532.3885 - false_positives: 2036.4586 - loss: 0.4122
# Epoch 3: val_loss did not improve from 0.43699
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8245 - false_negatives: 1543.7532 - false_positives: 2047.5380 - loss: 0.4122 - val_binary_accuracy: 0.7642 - val_false_negatives: 1092.0000 - val_false_positives: 87.0000 - val_loss: 0.5002
# Epoch 4/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8406 - false_negatives: 1448.6688 - false_positives: 1728.1847 - loss: 0.3818
# Epoch 4: val_loss improved from 0.43699 to 0.37609, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.8406 - false_negatives: 1458.9684 - false_positives: 1737.9430 - loss: 0.3818 - val_binary_accuracy: 0.8280 - val_false_negatives: 663.0000 - val_false_positives: 197.0000 - val_loss: 0.3761
# Epoch 5/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8579 - false_negatives: 1352.2993 - false_positives: 1545.2993 - loss: 0.3479
# Epoch 5: val_loss did not improve from 0.37609
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - binary_accuracy: 0.8578 - false_negatives: 1361.7975 - false_positives: 1554.1013 - loss: 0.3479 - val_binary_accuracy: 0.8306 - val_false_negatives: 663.0000 - val_false_positives: 184.0000 - val_loss: 0.3849
# Epoch 6/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8703 - false_negatives: 1241.3185 - false_positives: 1406.2039 - loss: 0.3248
# Epoch 6: val_loss improved from 0.37609 to 0.34746, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.8703 - false_negatives: 1250.0823 - false_positives: 1414.3102 - loss: 0.3249 - val_binary_accuracy: 0.8468 - val_false_negatives: 506.0000 - val_false_positives: 260.0000 - val_loss: 0.3475
# Epoch 7/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8783 - false_negatives: 1170.6815 - false_positives: 1329.9491 - loss: 0.3094
# Epoch 7: val_loss did not improve from 0.34746
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.8783 - false_negatives: 1179.0063 - false_positives: 1337.7468 - loss: 0.3095 - val_binary_accuracy: 0.8228 - val_false_negatives: 732.0000 - val_false_positives: 154.0000 - val_loss: 0.3841
# Epoch 8/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8864 - false_negatives: 1085.0128 - false_positives: 1218.4935 - loss: 0.2882
# Epoch 8: val_loss improved from 0.34746 to 0.32829, saving model to FullModelCheckpoint.keras
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.8863 - false_negatives: 1101.1646 - false_positives: 1233.7405 - loss: 0.2884 - val_binary_accuracy: 0.8570 - val_false_negatives: 298.0000 - val_false_positives: 417.0000 - val_loss: 0.3283
# Epoch 9/20
# 156/157 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8952 - false_negatives: 1003.4808 - false_positives: 1144.9487 - loss: 0.2756
# Epoch 9: val_loss did not improve from 0.32829
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - binary_accuracy: 0.8951 - false_negatives: 1018.4747 - false_positives: 1158.4937 - loss: 0.2757 - val_binary_accuracy: 0.8348 - val_false_negatives: 652.0000 - val_false_positives: 174.0000 - val_loss: 0.3631
# Epoch 10/20
# 155/157 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.9023 - false_negatives: 956.3871 - false_positives: 1051.6322 - loss: 0.2614
# Epoch 10: val_loss did not improve from 0.32829
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.9021 - false_negatives: 978.0949 - false_positives: 1071.4810 - loss: 0.2616 - val_binary_accuracy: 0.8608 - val_false_negatives: 327.0000 - val_false_positives: 369.0000 - val_loss: 0.3303
# Epoch 11/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9046 - false_negatives: 907.3057 - false_positives: 1063.8472 - loss: 0.2503
# Epoch 11: val_loss did not improve from 0.32829
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.9045 - false_negatives: 913.9620 - false_positives: 1070.2216 - loss: 0.2503 - val_binary_accuracy: 0.8602 - val_false_negatives: 365.0000 - val_false_positives: 334.0000 - val_loss: 0.3332
# Epoch 12/20
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9143 - false_negatives: 879.3949 - false_positives: 926.2293 - loss: 0.2349
# Epoch 12: val_loss did not improve from 0.32829
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - binary_accuracy: 0.9143 - false_negatives: 885.7848 - false_positives: 932.2342 - loss: 0.2350 - val_binary_accuracy: 0.8556 - val_false_negatives: 366.0000 - val_false_positives: 356.0000 - val_loss: 0.3351
# Epoch 12: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8525999784469604, 'false_negatives': 322.0, 'false_positives': 415.0, 'loss': 0.33167850971221924}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.keras", save_best_only=True, verbose=1
    )
    # Here, patience is set to 4. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=4, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = ops.where(ops.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives = model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=4, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.keras")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 150, 128)       │       384,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 150, 64)        │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_1          │ (None, 64)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 20)             │         1,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 426,537 (1.63 MB)
#  Trainable params: 426,537 (1.63 MB)
#  Non-trainable params: 0 (0.00 B)
# Starting to train with 15000 samples
# Epoch 1/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.5196 - false_negatives_1: 2020.2881 - false_positives_1: 1648.0339 - loss: 0.6923
# Epoch 1: val_loss improved from inf to 0.68542, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 46ms/step - binary_accuracy: 0.5198 - false_negatives_1: 2045.9667 - false_positives_1: 1678.8334 - loss: 0.6923 - val_binary_accuracy: 0.5844 - val_false_negatives_1: 1894.0000 - val_false_positives_1: 184.0000 - val_loss: 0.6854
# Epoch 2/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.5963 - false_negatives_1: 1580.7894 - false_positives_1: 1395.6316 - loss: 0.6771
# Epoch 2: val_loss improved from 0.68542 to 0.62817, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.5971 - false_negatives_1: 1647.5333 - false_positives_1: 1471.2667 - loss: 0.6765 - val_binary_accuracy: 0.6552 - val_false_negatives_1: 1598.0000 - val_false_positives_1: 126.0000 - val_loss: 0.6282
# Epoch 3/20
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.6772 - false_negatives_1: 1086.4407 - false_positives_1: 1351.8136 - loss: 0.6199
# Epoch 3: val_loss improved from 0.62817 to 0.55324, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - binary_accuracy: 0.6775 - false_negatives_1: 1101.3167 - false_positives_1: 1372.8334 - loss: 0.6197 - val_binary_accuracy: 0.7104 - val_false_negatives_1: 158.0000 - val_false_positives_1: 1290.0000 - val_loss: 0.5532
# Epoch 4/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7314 - false_negatives_1: 806.4561 - false_positives_1: 1158.2982 - loss: 0.5556
# Epoch 4: val_loss improved from 0.55324 to 0.47119, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - binary_accuracy: 0.7321 - false_negatives_1: 845.8000 - false_positives_1: 1212.3833 - loss: 0.5549 - val_binary_accuracy: 0.7716 - val_false_negatives_1: 217.0000 - val_false_positives_1: 925.0000 - val_loss: 0.4712
# Epoch 5/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.7663 - false_negatives_1: 754.0000 - false_positives_1: 921.6491 - loss: 0.5101
# Epoch 5: val_loss improved from 0.47119 to 0.41180, saving model to AL_Model.keras
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - binary_accuracy: 0.7670 - false_negatives_1: 790.5000 - false_positives_1: 965.0167 - loss: 0.5088 - val_binary_accuracy: 0.8184 - val_false_negatives_1: 490.0000 - val_false_positives_1: 418.0000 - val_loss: 0.4118
# Epoch 6/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8000 - false_negatives_1: 687.3793 - false_positives_1: 813.6207 - loss: 0.4577
# Epoch 6: val_loss did not improve from 0.41180
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8001 - false_negatives_1: 711.4000 - false_positives_1: 838.1667 - loss: 0.4575 - val_binary_accuracy: 0.7440 - val_false_negatives_1: 80.0000 - val_false_positives_1: 1200.0000 - val_loss: 0.5315
# Epoch 7/20
# 57/59 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - binary_accuracy: 0.8021 - false_negatives_1: 678.6667 - false_positives_1: 734.1754 - loss: 0.4489
# Epoch 7: val_loss did not improve from 0.41180
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - binary_accuracy: 0.8026 - false_negatives_1: 710.9333 - false_positives_1: 770.8000 - loss: 0.4478 - val_binary_accuracy: 0.7750 - val_false_negatives_1: 986.0000 - val_false_positives_1: 139.0000 - val_loss: 0.4714
# Epoch 8/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8236 - false_negatives_1: 623.4655 - false_positives_1: 669.6035 - loss: 0.4077
# Epoch 8: val_loss did not improve from 0.41180
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8239 - false_negatives_1: 643.2167 - false_positives_1: 690.5500 - loss: 0.4073 - val_binary_accuracy: 0.7522 - val_false_negatives_1: 69.0000 - val_false_positives_1: 1170.0000 - val_loss: 0.5528
# Epoch 9/20
# 58/59 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8330 - false_negatives_1: 575.0517 - false_positives_1: 630.7586 - loss: 0.3979
# Epoch 9: val_loss did not improve from 0.41180
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8333 - false_negatives_1: 594.0500 - false_positives_1: 650.0000 - loss: 0.3972 - val_binary_accuracy: 0.8100 - val_false_negatives_1: 758.0000 - val_false_positives_1: 192.0000 - val_loss: 0.4194
# Epoch 9: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 801.0, Number of ones incorrectly classified: 187.0
# Sample ratio for positives: 0.18927125506072875, Sample ratio for negatives:0.8107287449392713
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 78/79 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - binary_accuracy: 0.8167 - false_negatives_2: 908.7949 - false_positives_2: 833.7949 - loss: 0.4177
# Epoch 1: val_loss did not improve from 0.41180
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - binary_accuracy: 0.8172 - false_negatives_2: 929.2000 - false_positives_2: 852.2750 - loss: 0.4169 - val_binary_accuracy: 0.8028 - val_false_negatives_2: 805.0000 - val_false_positives_2: 181.0000 - val_loss: 0.4210
# Epoch 2/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8557 - false_negatives_2: 806.7215 - false_positives_2: 656.0380 - loss: 0.3485
# Epoch 2: val_loss improved from 0.41180 to 0.39811, saving model to AL_Model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8557 - false_negatives_2: 816.0375 - false_positives_2: 664.1750 - loss: 0.3485 - val_binary_accuracy: 0.8190 - val_false_negatives_2: 702.0000 - val_false_positives_2: 203.0000 - val_loss: 0.3981
# Epoch 3/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8672 - false_negatives_2: 731.2532 - false_positives_2: 635.0380 - loss: 0.3419
# Epoch 3: val_loss improved from 0.39811 to 0.37688, saving model to AL_Model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8671 - false_negatives_2: 740.2375 - false_positives_2: 643.0750 - loss: 0.3419 - val_binary_accuracy: 0.8320 - val_false_negatives_2: 211.0000 - val_false_positives_2: 629.0000 - val_loss: 0.3769
# Epoch 4/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8684 - false_negatives_2: 691.6456 - false_positives_2: 619.3544 - loss: 0.3312
# Epoch 4: val_loss improved from 0.37688 to 0.34857, saving model to AL_Model.keras
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - binary_accuracy: 0.8685 - false_negatives_2: 699.7375 - false_positives_2: 626.4750 - loss: 0.3311 - val_binary_accuracy: 0.8542 - val_false_negatives_2: 353.0000 - val_false_positives_2: 376.0000 - val_loss: 0.3486
# Epoch 5/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8771 - false_negatives_2: 697.2532 - false_positives_2: 565.8354 - loss: 0.3101
# Epoch 5: val_loss did not improve from 0.34857
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - binary_accuracy: 0.8771 - false_negatives_2: 705.5000 - false_positives_2: 572.7750 - loss: 0.3101 - val_binary_accuracy: 0.8160 - val_false_negatives_2: 748.0000 - val_false_positives_2: 172.0000 - val_loss: 0.4155
# Epoch 6/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8893 - false_negatives_2: 622.5823 - false_positives_2: 512.7215 - loss: 0.2885
# Epoch 6: val_loss did not improve from 0.34857
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.8892 - false_negatives_2: 630.3000 - false_positives_2: 519.2000 - loss: 0.2885 - val_binary_accuracy: 0.7722 - val_false_negatives_2: 1045.0000 - val_false_positives_2: 94.0000 - val_loss: 0.5559
# Epoch 7/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8931 - false_negatives_2: 599.1646 - false_positives_2: 472.8481 - loss: 0.2859
# Epoch 7: val_loss did not improve from 0.34857
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.8932 - false_negatives_2: 606.1125 - false_positives_2: 478.7250 - loss: 0.2859 - val_binary_accuracy: 0.8536 - val_false_negatives_2: 280.0000 - val_false_positives_2: 452.0000 - val_loss: 0.3699
# Epoch 8/20
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9018 - false_negatives_2: 565.0380 - false_positives_2: 445.5949 - loss: 0.2704
# Epoch 8: val_loss did not improve from 0.34857
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.9018 - false_negatives_2: 572.0500 - false_positives_2: 451.3875 - loss: 0.2704 - val_binary_accuracy: 0.8386 - val_false_negatives_2: 192.0000 - val_false_positives_2: 615.0000 - val_loss: 0.4006
# Epoch 8: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 382.0, Number of ones incorrectly classified: 386.0
# Sample ratio for positives: 0.5026041666666666, Sample ratio for negatives:0.4973958333333333
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - binary_accuracy: 0.8601 - false_negatives_3: 929.1938 - false_positives_3: 769.3571 - loss: 0.3518
# Epoch 1: val_loss did not improve from 0.34857
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 35ms/step - binary_accuracy: 0.8601 - false_negatives_3: 938.0303 - false_positives_3: 776.8283 - loss: 0.3516 - val_binary_accuracy: 0.8444 - val_false_negatives_3: 451.0000 - val_false_positives_3: 327.0000 - val_loss: 0.3518
# Epoch 2/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8893 - false_negatives_3: 773.5000 - false_positives_3: 648.6875 - loss: 0.2942
# Epoch 2: val_loss did not improve from 0.34857
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.8891 - false_negatives_3: 798.1919 - false_positives_3: 669.7879 - loss: 0.2946 - val_binary_accuracy: 0.8238 - val_false_negatives_3: 679.0000 - val_false_positives_3: 202.0000 - val_loss: 0.3905
# Epoch 3/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8895 - false_negatives_3: 779.3402 - false_positives_3: 624.2371 - loss: 0.2865
# Epoch 3: val_loss did not improve from 0.34857
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - binary_accuracy: 0.8894 - false_negatives_3: 795.2525 - false_positives_3: 637.1414 - loss: 0.2867 - val_binary_accuracy: 0.7904 - val_false_negatives_3: 936.0000 - val_false_positives_3: 112.0000 - val_loss: 0.4799
# Epoch 4/20
# 96/98 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8907 - false_negatives_3: 748.9479 - false_positives_3: 604.9479 - loss: 0.2841
# Epoch 4: val_loss did not improve from 0.34857
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.8907 - false_negatives_3: 771.8384 - false_positives_3: 623.8889 - loss: 0.2842 - val_binary_accuracy: 0.8468 - val_false_negatives_3: 460.0000 - val_false_positives_3: 306.0000 - val_loss: 0.3565
# Epoch 5/20
# 97/98 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9047 - false_negatives_3: 671.5876 - false_positives_3: 556.2783 - loss: 0.2574
# Epoch 5: val_loss did not improve from 0.34857
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.9046 - false_negatives_3: 686.1414 - false_positives_3: 568.4949 - loss: 0.2576 - val_binary_accuracy: 0.8434 - val_false_negatives_3: 502.0000 - val_false_positives_3: 281.0000 - val_loss: 0.3645
# Epoch 5: early stopping
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 382.0, Number of ones incorrectly classified: 386.0
# Sample ratio for positives: 0.5026041666666666, Sample ratio for negatives:0.4973958333333333
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - binary_accuracy: 0.8614 - false_negatives_4: 1067.3793 - false_positives_4: 984.5345 - loss: 0.3591
# Epoch 1: val_loss did not improve from 0.34857
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - binary_accuracy: 0.8614 - false_negatives_4: 1095.7646 - false_positives_4: 1009.1681 - loss: 0.3587 - val_binary_accuracy: 0.8448 - val_false_negatives_4: 223.0000 - val_false_positives_4: 553.0000 - val_loss: 0.3583
# Epoch 2/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - binary_accuracy: 0.8784 - false_negatives_4: 1025.9658 - false_positives_4: 849.0256 - loss: 0.3104
# Epoch 2: val_loss did not improve from 0.34857
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - binary_accuracy: 0.8783 - false_negatives_4: 1043.4790 - false_positives_4: 863.6302 - loss: 0.3105 - val_binary_accuracy: 0.7666 - val_false_negatives_4: 73.0000 - val_false_positives_4: 1094.0000 - val_loss: 0.5383
# Epoch 3/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - binary_accuracy: 0.8843 - false_negatives_4: 938.0085 - false_positives_4: 838.2881 - loss: 0.3010
# Epoch 3: val_loss improved from 0.34857 to 0.33930, saving model to AL_Model.keras
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - binary_accuracy: 0.8843 - false_negatives_4: 946.2941 - false_positives_4: 845.2857 - loss: 0.3011 - val_binary_accuracy: 0.8532 - val_false_negatives_4: 319.0000 - val_false_positives_4: 415.0000 - val_loss: 0.3393
# Epoch 4/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.8944 - false_negatives_4: 887.1368 - false_positives_4: 752.3504 - loss: 0.2842
# Epoch 4: val_loss did not improve from 0.33930
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - binary_accuracy: 0.8943 - false_negatives_4: 902.3782 - false_positives_4: 765.2857 - loss: 0.2843 - val_binary_accuracy: 0.8552 - val_false_negatives_4: 274.0000 - val_false_positives_4: 450.0000 - val_loss: 0.3511
# Epoch 5/20
# 116/118 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - binary_accuracy: 0.8950 - false_negatives_4: 885.1293 - false_positives_4: 704.8276 - loss: 0.2761
# Epoch 5: val_loss did not improve from 0.33930
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - binary_accuracy: 0.8949 - false_negatives_4: 907.6135 - false_positives_4: 723.4790 - loss: 0.2762 - val_binary_accuracy: 0.8314 - val_false_negatives_4: 672.0000 - val_false_positives_4: 171.0000 - val_loss: 0.3915
# Epoch 6/20
# 117/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9017 - false_negatives_4: 819.0000 - false_positives_4: 667.1368 - loss: 0.2575
# Epoch 6: val_loss did not improve from 0.33930
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - binary_accuracy: 0.9017 - false_negatives_4: 832.7983 - false_positives_4: 678.9664 - loss: 0.2576 - val_binary_accuracy: 0.8528 - val_false_negatives_4: 288.0000 - val_false_positives_4: 448.0000 - val_loss: 0.3546
# Epoch 7/20
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - binary_accuracy: 0.9100 - false_negatives_4: 737.5847 - false_positives_4: 651.7712 - loss: 0.2470
# Epoch 7: val_loss did not improve from 0.33930
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - binary_accuracy: 0.9099 - false_negatives_4: 744.1093 - false_positives_4: 657.4034 - loss: 0.2471 - val_binary_accuracy: 0.8384 - val_false_negatives_4: 560.0000 - val_false_positives_4: 248.0000 - val_loss: 0.3944
# Epoch 7: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'binary_accuracy': 0.8507999777793884, 'false_negatives_4': 346.0, 'false_positives_4': 400.0, 'loss': 0.34282028675079346}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
# Active Learning is a growing area of research. This example demonstrates the cost-efficiency
# benefits of using Active Learning, as it eliminates the need to annotate large amounts of
# data, saving resources.
#
# The following are some noteworthy observations from this example:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full dataset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
#
# For further reading about the types of sampling ratios, training techniques or available
# open source libraries/implementations, you can refer to the resources below:
#
# 1. [Active Learning Literature Survey](http://burrsettles.com/pub/settles.activelearning.pdf) (Burr Settles, 2010).
# 2. [modAL](https://github.com/modAL-python/modAL): A Modular Active Learning framework.
# 3. Google's unofficial [Active Learning playground](https://github.com/google/active-learning).
